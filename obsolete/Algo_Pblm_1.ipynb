# %%
import pandas as pd
import re
import nltk
import plotly.express as px
import matplotlib.pyplot as plt
from nltk.tokenize import RegexpTokenizer
from wordcloud import WordCloud
from nltk.sentiment.vader import SentimentIntensityAnalyzer
nltk.download('stopwords')
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Jia
# [nltk_data]     Herng\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to C:\Users\Jia
# [nltk_data]     Herng\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
article_word_cnt_USA = []
article_word_cnt_TL = []
article_word_cnt_NZ = []
article_word_cnt_HK = []
article_word_cnt_DB = []
all_lists_USA = []
all_lists_TL = []
all_lists_NZ = []
all_lists_HK = []
all_lists_DB = []

stop_words = nltk.corpus.stopwords.words('english')

# %% [markdown]
# **USA **

# %%
pd.set_option('display.max_colwidth', 500)
cnt = 1
for i in range(5):
    df = pd.read_csv(r"./content/US {0}.txt".format(cnt), delimiter='\t', header=None)
    df.columns = ['Paragraphs']
    print(f"\nUSA {cnt}\n")
    cnt += 1
    # calculate total word count of article
    for j in range(len(df.index)):
      article = [paragraphs for paragraphs in df['Paragraphs']]
      article_word_cnt_USA += article[j]

    # convert the paragraphs into token
    def tokenize(text):
      tokens = re.split("\W+", text)
      return tokens
    df['Tokenized message'] = df['Paragraphs'].apply(lambda x: tokenize(x.lower()))

    #remove stopwords and empty strings from the list
    def removeStopwords(tokenized):
      filtered = [i for i in tokenized if i not in stop_words]
      while " " in all_lists_USA:
        all_lists_USA.remove(" ")
      return filtered
    # get filtered word list
    df['Filtered'] = df['Tokenized message'].apply(lambda x: removeStopwords(x))
    print(df)
    for j in range(len(df.index)):
      all_words = [paragraphs for paragraphs in df['Filtered']]
      all_lists_USA += all_words[j]

print(f'Filtered list: {all_lists_USA}')

wordcloud = WordCloud(width = 1000, height = 1000,
                      min_font_size = 10).generate(str(all_lists_USA))
plt.figure(figsize=(8,8), facecolor=None)
plt.imshow(wordcloud)
plt.axis('off')
plt.tight_layout(pad = 0)
plt.show()
# Out:
# USA 1
#
#                                                                                                                                                                                                                                                                                                                                      Paragraphs  \
# 0                                                                                                                                                                                                                                                                     Biden admits the US economy has ‘problems,’ warns of ‘haul’ before relief
# ...

# %% [markdown]
# **Thailand**

# %%
cnt = 1
for i in range(5):
    df = pd.read_csv(r"./content/TH {0}.txt".format(cnt), delimiter='\t', header=None)
    df.columns = ['Paragraphs']
    print(f"\nThailand {cnt}\n")
    cnt += 1
    # calculate total word count of article
    for j in range(len(df.index)):
      article = [paragraphs for paragraphs in df['Paragraphs']]
      article_word_cnt_TL += article[j]

    # convert the paragraphs into token
    def tokenize(text):
      tokens = re.split("\W+", text)
      return tokens
    df['Tokenized message'] = df['Paragraphs'].apply(lambda x: tokenize(x.lower()))

    #remove stopwords and empty strings from the list
    def removeStopwords(tokenized):
      filtered = [i for i in tokenized if i not in stop_words]
      while " " in all_lists_TL:
          all_lists_TL.remove(" ")
      return filtered
    # get filtered word list
    df['Filtered'] = df['Tokenized message'].apply(lambda x: removeStopwords(x))
    print(df)
    for j in range(len(df.index)):
      all_words = [paragraphs for paragraphs in df['Filtered']]
      all_lists_TL += all_words[j]

print(f'Filtered list: {all_lists_TL}')

wordcloud = WordCloud(width = 1000, height = 1000,
                      min_font_size = 10).generate(str(all_lists_TL))
plt.figure(figsize=(8,8), facecolor=None)
plt.imshow(wordcloud)
plt.axis('off')
plt.tight_layout(pad = 0)
plt.show()
# Out:
# Thailand 1
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Paragraphs  \
# ...

# %% [markdown]
# **New Zealand**

# %%
cnt = 1
for i in range(5):
    df = pd.read_csv(r"./content/NZ {0}.txt".format(cnt), delimiter='\t', header=None)
    df.columns = ['Paragraphs']
    print(f"\nNew Zealand {cnt}\n")
    cnt += 1
    # calculate total word count of article
    for j in range(len(df.index)):
      article = [paragraphs for paragraphs in df['Paragraphs']]
      article_word_cnt_NZ += article[j]

    # convert the paragraphs into token
    def tokenize(text):
      tokens = re.split("\W+", text)
      return tokens
    df['Tokenized message'] = df['Paragraphs'].apply(lambda x: tokenize(x.lower()))

    #remove stopwords and empty strings from the list
    def removeStopwords(tokenized):
      filtered = [i for i in tokenized if i not in stop_words]
      while " " in all_lists_NZ:
          all_lists_NZ.remove(" ")
      return filtered
    # get filtered word list
    df['Filtered'] = df['Tokenized message'].apply(lambda x: removeStopwords(x))
    print(df)
    for j in range(len(df.index)):
      all_words = [paragraphs for paragraphs in df['Filtered']]
      all_lists_NZ += all_words[j]

print(f'Filtered list: {all_lists_NZ}')

wordcloud = WordCloud(width = 1000, height = 1000,
                      min_font_size = 10).generate(str(all_lists_NZ))
plt.figure(figsize=(8,8), facecolor=None)
plt.imshow(wordcloud)
plt.axis('off')
plt.tight_layout(pad = 0)
plt.show()
# Out:
# New Zealand 1
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              Paragraphs  \
# ...

# %% [markdown]
# **Hong Kong**

# %%
cnt = 1
for i in range(5):
    df = pd.read_csv(r"./content/CN {0}.txt".format(cnt), delimiter='\t', header=None)
    df.columns = ['Paragraphs']
    print(f"\nHong Kong {cnt}\n")
    cnt += 1
    # calculate total word count of article
    for j in range(len(df.index)):
      article = [paragraphs for paragraphs in df['Paragraphs']]
      article_word_cnt_HK += article[j]

    # convert the paragraphs into token
    def tokenize(text):
      tokens = re.split("\W+", text)
      return tokens
    df['Tokenized message'] = df['Paragraphs'].apply(lambda x: tokenize(x.lower()))

    #remove stopwords and empty strings from the list
    def removeStopwords(tokenized):
      filtered = [i for i in tokenized if i not in stop_words]
      while " " in all_lists_TL:
          all_lists_HK.remove(" ")
      return filtered
    # get filtered word list
    df['Filtered'] = df['Tokenized message'].apply(lambda x: removeStopwords(x))
    print(df)
    for j in range(len(df.index)):
      all_words = [paragraphs for paragraphs in df['Filtered']]
      all_lists_HK += all_words[j]

print(f'Filtered list: {all_lists_HK}')

wordcloud = WordCloud(width = 1000, height = 1000,
                      min_font_size = 10).generate(str(all_lists_HK))
plt.figure(figsize=(8,8), facecolor=None)
plt.imshow(wordcloud)
plt.axis('off')
plt.tight_layout(pad = 0)
plt.show()
# Out:
# Hong Kong 1
#
#                                                                                                                                                                                                                                                                                                                                 Paragraphs  \
# 0                                                                                                                                                                                                                           Alibaba, Kuaishou pace Hong Kong stock losses on tech earnings outlook while Beijing faces tighter Covid rules
# ...

# %% [markdown]
# **United Arab Emirates**

# %%
cnt = 1
for i in range(5):
    df = pd.read_csv(r"./content/AE {0}.txt".format(cnt), delimiter='\t', header=None)
    df.columns = ['Paragraphs']
    print(f"\nDubai {cnt}\n")
    cnt += 1
    # calculate total word count of article
    for j in range(len(df.index)):
      article = [paragraphs for paragraphs in df['Paragraphs']]
      article_word_cnt_DB += article[j]

    # convert the paragraphs into token
    def tokenize(text):
      tokens = re.split("\W+", text)
      return tokens
    df['Tokenized message'] = df['Paragraphs'].apply(lambda x: tokenize(x.lower()))

    #remove stopwords and empty strings from the list
    def removeStopwords(tokenized):
      filtered = [i for i in tokenized if i not in stop_words]
      while " " in all_lists_TL:
          all_lists_DB.remove(" ")
      return filtered
    # get filtered word list
    df['Filtered'] = df['Tokenized message'].apply(lambda x: removeStopwords(x))
    print(df)
    for j in range(len(df.index)):
      all_words = [paragraphs for paragraphs in df['Filtered']]
      all_lists_DB += all_words[j]

print(f'Filtered list: {all_lists_DB}')

wordcloud = WordCloud(width = 1000, height = 1000,
                      min_font_size = 10).generate(str(all_lists_DB))
plt.figure(figsize=(8,8), facecolor=None)
plt.imshow(wordcloud)
plt.axis('off')
plt.tight_layout(pad = 0)
plt.show()
# Out:
# Dubai 1
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              Paragraphs  \
# ...

# %% [markdown]
# Plotting Graph

# %%
dataFrame = pd.DataFrame({"Country":['United States of America', 'Thailand', 'New Zealand', 'Hong Kong', 'United Arab Emirates'],
                           "Total word count": [len(article_word_cnt_USA), len(article_word_cnt_TL), len(article_word_cnt_NZ), len(article_word_cnt_HK), len(article_word_cnt_DB)],
                           "Number of stopwords": [len(article_word_cnt_USA) - len(all_lists_USA), len(article_word_cnt_TL) - len(all_lists_TL), len(article_word_cnt_NZ) - len(all_lists_NZ), len(article_word_cnt_HK) - len(all_lists_HK), len(article_word_cnt_DB) - len(all_lists_DB)],
                           "Filtered word count": [len(all_lists_USA), len(all_lists_TL), len(all_lists_NZ), len(all_lists_HK), len(all_lists_DB)]})
print()
print(dataFrame)
# Out:
#                     Country  Total word count  Number of stopwords  \
# 0  United States of America             26220                23416
# 1                  Thailand             23855                21355
# 2               New Zealand             19086                17047
# 3                 Hong Kong             15365                13585
# 4      United Arab Emirates             13624                12163
#
#    Filtered word count
# 0                 2804
# 1                 2500
# 2                 2039
# 3                 1780
# 4                 1461

# %%
fig = px.bar(dataFrame, x='Country', y=['Total word count', 'Number of stopwords', 'Filtered word count'], title='Word count')
fig.show()
# Out:
# <div>                            <div id="c4abff41-bfeb-487d-a1c2-f9e4801c1aa1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c4abff41-bfeb-487d-a1c2-f9e4801c1aa1")) {                    Plotly.newPlot(                        "c4abff41-bfeb-487d-a1c2-f9e4801c1aa1",                        [{"alignmentgroup":"True","hovertemplate":"variable=Total word count<br>Country=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Total word count","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Total word count","offsetgroup":"Total word count","orientation":"v","showlegend":true,"textposition":"auto","x":["United States of America","Thailand","New Zealand","Hong Kong","United Arab Emirates"],"xaxis":"x","y":[26220,23855,19086,15365,13624],"yaxis":"y
# ...

# %% [markdown]
# **Sentiment Analysis**

# %%
# latest 5/6/22
# updated graph plotting
pos_ranklist=[]
pos_country=[]
neg_ranklist=[]
neg_country=[]

class SentimentAnalysis():

    def __init__(self, countryList, countryName):
        self.countryName = countryName
        self.countryList = countryList
        #self.sentimentAnalysis(countryName,countryList)

    def sentimentAnalysis(countryName,countryList):
        list=countryList
        global pos_ranklist
        global neg_ranklist
    
        print()
        print(countryName)
        posper = positive(list)
        negper = negative(list)
        neutper = neutral(list,posper,negper)
    
        #plot pie chart of each countries
        labels = 'Positive', 'Negative', 'Neutral'
        percentage = [posper[0], negper[0], neutper]
        explode = (0, 0.2, 0.2)
        plt.pie(percentage, explode=explode, labels=labels, autopct='%1.1f%%')
        plt.title(f'\nSentiment analysis of {countryName}')
        plt.legend()
        plt.show()

        if posper > negper:
            print("Overall positive \n")
            pos_ranklist.append(posper[0])
            pos_country.append(countryName)
        
        else:
            print('Overall negative \n')
            neg_ranklist.append(negper[0])
            neg_country.append(countryName)
	

    def ranking(r1,r2,n1,n2):
        ranking=[]
        for i in range(len(r1)):
            for j in range(i+1,len(r1)):
                if r1[i]<r1[j]:
                    r1[i],r1[j]=r1[j],r1[i]
                    n1[i],n1[j]=n1[j],n1[i]

        for i in range(len(r2)):
            for j in range(i+1,len(r2)):
                if r2[i]>r2[j]:
                    r2[i],r2[j]=r2[j],r2[i]
                    n2[i],n2[j]=n2[j],n2[i]

    ranking=n1+n2
    print(ranking)
    #r1.sort(reverse = True)
    #r2.sort()
    #ranking=r1+r2
    #print(ranking[:3])

    positiveWords = []
    negativeWords = []
    neutralWords = []
    #plot word count of positive words

def KMPSearch(pat, txt):
    count = 0	
    M = len(pat)
    N = len(txt)

    # create lps[] that will hold the longest prefix suffix
    # values for pattern
    lps = [0]*M
    j = 0  # index for pat[]

    # Preprocess the pattern (calculate lps[] array)
    computeLPSArray(pat, M, lps)

    if M == N:
        i = 0  # index for txt[]
        while i < N:
            if pat[j] == txt[i]:
                i += 1
                j += 1

            if j == M:
                #print ("Found pattern at index", str(i-j))
                j = lps[j-1]
                count = count+1
								

            # mismatch after j matches
            elif i < N and pat[j] != txt[i]:
                # Do not match lps[0..lps[j-1]] characters,
                # they will match anyway
                if j != 0:
                    j = lps[j-1]
                else:
                    i += 1
    return count


def computeLPSArray(pat, M, lps):
    len = 0  # length of the previous longest prefix suffix

    lps[0]  # lps[0] is always 0
    i = 1

    # the loop calculates lps[i] for i = 1 to M-1
    while i < M:
        if pat[i] == pat[len]:
            len += 1
            lps[i] = len
            i += 1
        else:
            # This is tricky. Consider the example.
            # AAACAAAA and i = 7. The idea is similar
            # to search step.
            if len != 0:
                len = lps[len-1]

                # Also, note that we do not increment i here
            else:
                lps[i] = 0
                i += 1


def positive(list):
    pos = open("./content/Positive.txt", encoding="utf8")
    pos = pos.read().splitlines()
    pos_count = 0
    for x in range(len(list)):
        for y in range(len(pos)):
            pos_count = pos_count + KMPSearch(pos[y], list[x])
    #print("Positive counts:", pos_count)
    posper = (pos_count/(len(list))*100)
    print("Positive Percentage: {:.2f}%" .format(posper))
    return posper, pos_count


def negative(list):
    neg = open("./content/Negative.txt", encoding="utf8")
    neg = neg.read().splitlines()
    neg_count = 0
    for x in range(len(list)):
        for y in range(len(neg)):
            neg_count = neg_count + KMPSearch(neg[y], list[x])
    #print("Negative counts:", neg_count)
    negper = (neg_count/(len(list))*100)
    print("Negative Percentage: {:.2f}%" .format(negper))
    return negper, neg_count

def neutral(list,p,n):
  neut_count= len(list)- p[1]- n[1]
  #print("Neutral counts:", neut_count)
  neutper = (neut_count/(len(list))*100)
  print("Neutral Percentage: {:.2f}%" .format(neutper))

  return '{:.2f}'.format(neutper)

if __name__ == "__main__":

    countryName = ('United States of America','Thailand','New Zealand', 'Hong Kong', 'United Arab Emirates')
    countryList= (all_lists_USA,all_lists_TL,all_lists_NZ,all_lists_HK,all_lists_DB)
    country= [SentimentAnalysis.sentimentAnalysis(countryName[i], countryList[i])\
            for i in range(5)]
    print("Ranking:")
    SentimentAnalysis.ranking(pos_ranklist,neg_ranklist,pos_country,neg_country)
# Out:
# United States of America
# Positive Percentage: 2.21%
# Negative Percentage: 4.89%
# Neutral Percentage: 92.90%
# Overall negative
#
#
# Thailand
# Positive Percentage: 3.92%
# Negative Percentage: 3.44%
# Neutral Percentage: 92.64%
# Overall positive
#
#
# New Zealand
# Positive Percentage: 3.09%
# Negative Percentage: 5.59%
# Neutral Percentage: 91.32%
# Overall negative
#
#
# Hong Kong
# Positive Percentage: 2.64%
# Negative Percentage: 4.89%
# Neutral Percentage: 92.47%
# Overall negative
#
#
# United Arab Emirates
# Positive Percentage: 6.37%
# Negative Percentage: 0.41%
# Neutral Percentage: 93.22%
# Overall positive
#
# Ranking:
# ['United Arab Emirates', 'Thailand', 'United States of America', 'Hong Kong', 'New Zealand']
# [2.211126961483595, 3.92, 3.089749877390878, 2.640449438202247, 6.365503080082135]
# [4.885877318116976, 3.44, 5.590975968612065, 4.885877318116976, 3.44, 5.590975968612065, 4.8876404494382015, 0.41067761806981523]
# Stored 'pos2' (list)
# ...

# %% [markdown]
# # Sentiment Analysis

# %%
#from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# function to print sentiments
# of the sentence.
def sentiment_scores(sentence, country):
 
    # Create a SentimentIntensityAnalyzer object.
    sid_obj = SentimentIntensityAnalyzer()
 
    # polarity_scores method of SentimentIntensityAnalyzer
    # object gives a sentiment dictionary.
    # which contains pos, neg, neu, and compound scores.
    sentiment_dict = sid_obj.polarity_scores(sentence)

    print(f'\nCountry: {country}') 
    print("Overall sentiment dictionary is: ", sentiment_dict)
    print("Articles are rated as ", sentiment_dict['neg']*100, "% Negative")
    print("Articles are rated as ", sentiment_dict['neu']*100, "% Neutral")
    print("Articles are rated as ", sentiment_dict['pos']*100, "% Positive")
 
    print("Economic Situation Overall is Rated As", end = " ")
 
    # decide sentiment as positive, negative and neutral
    if sentiment_dict['compound'] >= 0.05 :
        print("Positive")
 
    elif sentiment_dict['compound'] <= - 0.05 :
        print("Negative")
 
    else :
        print("Neutral")

# %%
sentiment_scores(' '.join([str(x) for x in all_lists_USA]), 'United States of America')
sentiment_scores(' '.join([str(x) for x in all_lists_TL]), 'Thailand')
sentiment_scores(' '.join([str(x) for x in all_lists_NZ]), 'New Zealand')
sentiment_scores(' '.join([str(x) for x in all_lists_HK]), 'Hong Kong')
sentiment_scores(' '.join([str(x) for x in all_lists_DB]), 'United Arab Emirates')
# Out:
# Country: United States of America
# Overall sentiment dictionary is:  {'neg': 0.147, 'neu': 0.769, 'pos': 0.084, 'compound': -0.9996}
# Articles are rated as  14.7 % Negative
# Articles are rated as  76.9 % Neutral
# Articles are rated as  8.4 % Positive
# Economic Situation Overall is Rated As Negative
#
# Country: Thailand
# Overall sentiment dictionary is:  {'neg': 0.074, 'neu': 0.751, 'pos': 0.175, 'compound': 0.9997}
# Articles are rated as  7.3999999999999995 % Negative
# Articles are rated as  75.1 % Neutral
# Articles are rated as  17.5 % Positive
# Economic Situation Overall is Rated As Positive
#
# Country: New Zealand
# Overall sentiment dictionary is:  {'neg': 0.141, 'neu': 0.751, 'pos': 0.107, 'compound': -0.9978}
# Articles are rated as  14.099999999999998 % Negative
# Articles are rated as  75.1 % Neutral
# Articles are rated as  10.7 % Positive
# Economic Situation Overall is Rated As Negative
#
# Country: Hong Kong
# ...

# %%
# Solved the bug
pos_ranklist=[]
neg_ranklist=[]

def KMPSearch(pat, txt):
    visited= False
    count = 0
    # global count
    M = len(pat)
    N = len(txt)

    # create lps[] that will hold the longest prefix suffix
    # values for pattern
    lps = [0]*M
    j = 0  # index for pat[]

    # Preprocess the pattern (calculate lps[] array)
    computeLPSArray(pat, M, lps)

    if M == N:
        i = 0  # index for txt[]
        while i < N:
            if pat[j] == txt[i]:
                i += 1
                j += 1

            if j == M:
                #print ("Found pattern at index", str(i-j))
                j = lps[j-1]
                count = count+1
                visited=True

            # mismatch after j matches
            elif i < N and pat[j] != txt[i]:
                # Do not match lps[0..lps[j-1]] characters,
                # they will match anyway
                if j != 0:
                    j = lps[j-1]
                else:
                    i += 1
    return count,visited


def computeLPSArray(pat, M, lps):
    len = 0  # length of the previous longest prefix suffix

    lps[0]  # lps[0] is always 0
    i = 1

    # the loop calculates lps[i] for i = 1 to M-1
    while i < M:
        if pat[i] == pat[len]:
            len += 1
            lps[i] = len
            i += 1
        else:
            # This is tricky. Consider the example.
            # AAACAAAA and i = 7. The idea is similar
            # to search step.
            if len != 0:
                len = lps[len-1]

                # Also, note that we do not increment i here
            else:
                lps[i] = 0
                i += 1


def sentimentAnalysis(list, country):
    global pos_ranklist
    global neg_ranklist
    print(country)
    posper = positive(list)
    negper = negative(list)
    neutral(list,posper,negper)
    if posper > negper:
        print("Overall positive \n")
        pos_ranklist.append(posper[0])

    else:
        print('Overall negative \n')
        neg_ranklist.append(negper[0])

def ranking(r1, r2):
    ranking=[]

    r1.sort(reverse = True)
    r2.sort()
    ranking=r1+r2
    print(ranking)
    print(ranking[:3])

def positive(list):
    pos = open("./content/Positive.txt", encoding="utf8")
    pos = pos.read().splitlines()
    pos_count = 0
    for x in range(len(list)):
        for y in range(len(pos)):
            pos_count = pos_count + KMPSearch(pos[y], list[x])[0]
            #if (KMPSearch(pos[x], list[y])[1])== True:
            #    print(y)
    #print("Positive counts:", pos_count)
    posper = (pos_count/(len(list))*100)
    print("Positive Percentage: {:.2f}%" .format(posper))

    return posper, pos_count


def negative(list):
    neg = open("./content/Negative.txt", encoding="utf8")
    neg = neg.read().splitlines()
    neg_count = 0
    for x in range(len(list)):
        for y in range(len(neg)):
            neg_count = neg_count + KMPSearch(neg[y], list[x])[0]
            #if (KMPSearch(neg[x], list[y])[1])== True:
            #  list= list.pop(y)
    #print("Negative counts:", neg_count)
    negper = (neg_count/(len(list))*100)
    print("Negative Percentage: {:.2f}%" .format(negper))

    return negper, neg_count

def neutral(list,p,n):
    neut_count= len(list)- p[1]- n[1]
    #print("Neutral counts:", neut_count)
    nuetper = (neut_count/(len(list))*100)
    print("Neutral Percentage: {:.2f}%" .format(nuetper))


if __name__ == "__main__":
    #sentimentAnalysis(all_lists_USA,'United States of America')
    sentimentAnalysis(all_lists_TL,'Thailand')
    #sentimentAnalysis(all_lists_NZ,'New Zealand')
    sentimentAnalysis(all_lists_HK,'Hong Kong')
    sentimentAnalysis(all_lists_DB,'United Arab Emirates')

    print("Ranking:")
    ranking(pos_ranklist,neg_ranklist)
# Out:
# Thailand
# Positive Percentage: 3.92%
# Negative Percentage: 3.44%
# Neutral Percentage: 92.64%
# Overall positive
#
# Hong Kong
# Positive Percentage: 2.64%
# Negative Percentage: 4.89%
# Neutral Percentage: 92.47%
# Overall negative
#
# United Arab Emirates
# Positive Percentage: 6.37%
# Negative Percentage: 0.41%
# Neutral Percentage: 93.22%
# Overall positive
#
# Ranking:
# [6.365503080082135, 3.92, 4.8876404494382015]
# [6.365503080082135, 3.92, 4.8876404494382015]
