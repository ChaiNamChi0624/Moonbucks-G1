# %%
import pandas as pd
import re
import nltk
from nltk.tokenize import RegexpTokenizer
from nltk.sentiment.vader import SentimentIntensityAnalyzer
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\hozhi\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
cnt = 1

df = pd.read_csv(r'C:\Users\hozhi\OneDrive - 365.um.edu.my\UM\WIA2005_ADA\Group\DB 1.txt'.format(cnt), delimiter='\t')
df.columns = ['Paragraphs']
print(f"\nDubai {cnt}\n", df)

cnt += 1

def tokenize(text):
    tokens = re.split("\W+", text)
    return tokens


df['Tokenized message'] = df['Paragraphs'].apply(
lambda x: tokenize(x.lower()))
print(df)

stop_words = nltk.corpus.stopwords.words('english')

def removeStopwords(tokenized):
    filtered = [i for i in tokenized if i not in stop_words]
    return filtered

df['Filtered'] = df['Tokenized message'].apply(lambda x: removeStopwords(x))
print(df)
# Out:
# Dubai 1
#                                             Paragraphs
# 0                               Omar Sultan Al Olama:
# 1   We aim to build global strategic partnerships ...
# 2   We aim to enhance Dubai’s digital infrastructu...
# 3   Dubai, UAE – Dubai Chamber of Digital Economy ...
# 4   The meeting was led by His Excellency Omar Sul...
# 5   The meeting outlined a wide range of initiativ...
# 6   “Dubai Chamber of Digital Economy reiterates i...
# 7   “We strive to support digital transformation p...
# 8   For his part, Iskandar Najjar said: “Dubai pos...
# 9   Dubai Chamber of Digital Economy is in the pro...
# 10  The Chamber has recently launched an integrate...
#                                            Paragraphs  \
# 0                               Omar Sultan Al Olama:
# 1   We aim to build global strategic partnerships ...
# 2   We aim to enhance Dubai’s digital infrastructu...
# 3   Dubai, UAE – Dubai Chamber of Digital Economy ...
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Paragraphs         11 non-null     object
#  1   Tokenized message  11 non-null     object
#  2   Filtered           11 non-null     object
# dtypes: object(3)
# memory usage: 392.0+ bytes
# None

# %%
print(df['Filtered'])
# Out:
# 0                           [omar, sultan, al, olama, ]
# 1     [aim, build, global, strategic, partnerships, ...
# 2     [aim, enhance, dubai, digital, infrastructure,...
# 3     [dubai, uae, dubai, chamber, digital, economy,...
# 4     [meeting, led, excellency, omar, sultan, al, o...
# 5     [meeting, outlined, wide, range, initiatives, ...
# 6     [, dubai, chamber, digital, economy, reiterate...
# 7     [, strive, support, digital, transformation, p...
# 8     [part, iskandar, najjar, said, dubai, possesse...
# 9     [dubai, chamber, digital, economy, process, de...
# 10    [chamber, recently, launched, integrated, stra...
# Name: Filtered, dtype: object

# %%
print(df.iloc[1,2])
# Out:
# ['aim', 'build', 'global', 'strategic', 'partnerships', 'employ', 'innovative', 'solutions', 'drive', 'growth', 'digital', 'businesses', 'dubai', 'uae', '']

# %%
paragraph = df.iloc[0,2]
print(paragraph)
# Out:
# ['omar', 'sultan', 'al', 'olama', '']

# %%
print(len(list(df.iloc[1, 2])))
# Out:
# 15

# %%
print(len(df.index))
words = []

for i in range(len(df.index)): 
    para = df.iloc[i, 2]
    for j in range (len(para)): 
        word = para[j]
        print(word)
        words.append(word)

# for i in range(df.size):
#     paragraph.append(list(df.iloc[i, 2]))
print(words)
# Out:
# 11
# omar
# sultan
# al
# olama
#
# aim
# build
# global
# strategic
# partnerships
# employ
# innovative
# solutions
# drive
# growth
# digital
# businesses
# dubai
# uae
#
# aim
# enhance
# dubai
# digital
# infrastructure
# cement
# role
# preferred
# hub
# digital
# businesses
#
# dubai
# uae
# dubai
# chamber
# digital
# economy
# one
# chambers
# operating
# dubai
# chambers
# recently
# held
# meeting
# equiti
# group
# headquarters
# aimed
# explore
# new
# ways
# boost
# growth
# digital
# economy
# sectors
#
# meeting
# led
# excellency
# omar
# sultan
# al
# olama
# minister
# state
# artificial
# intelligence
# digital
# economy
# remote
# work
# applications
# chairman
# dubai
# chamber
# digital
# economy
# equiti
# group
# ceo
# iskandar
# najjar
# representatives
# company
#
# meeting
# outlined
# wide
# range
# initiatives
# events
# designed
# support
# national
# strategy
# digital
# economy
# dubai
# uae
# meeting
# h
# e
# al
# olama
# highlighted
# importance
# ...

# %%
def getZarr(string, z):
	n = len(string)

	# [L,R] make a window which matches
	# with prefix of s
	l, r, k = 0, 0, 0
	for i in range(1, n):

		# if i>R nothing matches so we will calculate.
		# Z[i] using naive way.
		if i > r:
			l, r = i, i

			# R-L = 0 in starting, so it will start
			# checking from 0'th index. For example,
			# for "ababab" and i = 1, the value of R
			# remains 0 and Z[i] becomes 0. For string
			# "aaaaaa" and i = 1, Z[i] and R become 5
			while r < n and string[r - l] == string[r]:
				r += 1
			z[i] = r - l
			r -= 1
		else:

			# k = i-L so k corresponds to number which
			# matches in [L,R] interval.
			k = i - l

			# if Z[k] is less than remaining interval
			# then Z[i] will be equal to Z[k].
			# For example, str = "ababab", i = 3, R = 5
			# and L = 2
			if z[k] < r - i + 1:
				z[i] = z[k]

			# For example str = "aaaaaa" and i = 2,
			# R is 5, L is 0
			else:

				# else start from R and check manually
				l = i
				while r < n and string[r - l] == string[r]:
					r += 1
				z[i] = r - l
				r -= 1

# %%
# prints all occurrences of pattern
# in text using Z algo
def search(text, pattern):

	# Create concatenated string "P$T"
	concat = pattern + "$" + text
	l = len(concat)

	# Construct Z array
	z = [0] * l
	getZarr(concat, z)

	# now looping through Z array for matching condition
	for i in range(l):

		# if Z[i] (matched region) is equal to pattern
		# length we got the pattern
		if z[i] == len(pattern):
			print("Pattern found at index",
					i - len(pattern) - 1)

# %%
# # Driver Code
# if __name__ == "__main__":
# 	text = "GEEKS FOR GEEKS"
# 	pattern = "GEEK"
# 	search(text, pattern)

text = ''.join([str(x) for x in words])
pattern = 'attract'
search(text, pattern)
# Out:
# Pattern found at index 2169
