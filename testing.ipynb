# %%
from mapbox import Directions, Geocoder
import os
import folium
from folium.plugins import MarkerCluster

# %%
os.environ['MAPBOX_ACCESS_TOKEN'] ="pk.eyJ1IjoiY2hhaW5hbWNoaSIsImEiOiJjbDNoZHJtZGQwMTNiM2VvZ212djBiNG5hIn0.9OZgJgaQuyPSWOwGYqQvuA"
token = os.environ['MAPBOX_ACCESS_TOKEN']

geocoder = Geocoder(access_token=token)

# %%
coordinates_1 = [103.78655, 1.435163]
coordinates_2 = [103.862469, 1.301225]

origin = {
    'type': 'Feature',
#     'properties': {'name': 'Portland, OR'},
    'geometry': {
        'type': 'Point',
        'coordinates': coordinates_1
    }
}
destination = {
    'type': 'Feature',
#     'properties': {'name': 'Bend, OR'},
    'geometry': {
        'type': 'Point',
        'coordinates': coordinates_2
    }
}
# all_nodes = {0 : origin}

# %%
direction = Directions(access_token=token)

# %%
response = direction.directions([origin, destination], 'mapbox.driving')
response.status_code
# give html record
# Out:
# 200

# %%
path = response.geojson()['features'][0]['geometry']['coordinates']
response.geojson()
#response.geojson()['features'][0]
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'geometry': {'type': 'LineString',
#     'coordinates': [(103.78663, 1.43531),
#      (103.78774, 1.43521),
#      (103.78786, 1.43479),
#      (103.78861, 1.43499),
#      (103.78679, 1.4279),
#      (103.78701, 1.42661),
#      (103.7979, 1.42104),
#      (103.80476, 1.41568),
#      (103.81432, 1.3971),
#      (103.81666, 1.39506),
#      (103.8281, 1.39312),
#      (103.84254, 1.39646),
#      (103.852, 1.39699),
#      (103.85574, 1.39764),
#      (103.85795, 1.39468),
#      (103.85851, 1.37709),
#      (103.861, 1.3689),
#      (103.85694, 1.35497),
#      (103.86203, 1.33888),
#      (103.86237, 1.3291),
#      (103.85564, 1.32086),
#      (103.84783, 1.3167),
#      (103.84547, 1.31397),
#      (103.84488, 1.31107),
#      (103.85081, 1.30515),
#      (103.85936, 1.29982),
#      (103.86127, 1.30114),
#      (103.86115, 1.30088),
#      (103.86191, 1.30023),
#      (103.86257, 1.30129)]},
# ...

# %%
world_map = folium.Map()
world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
marker_cluster = MarkerCluster().add_to(world_map)
folium.Marker(
    location=[coordinates_1[1], coordinates_1[0]],
    icon=folium.Icon(color='red')
).add_to(marker_cluster)

folium.Marker(
    location=[coordinates_2[1], coordinates_2[0]],
    icon=folium.Icon(color='green')
).add_to(marker_cluster)

world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
index = 0
for coordinate in path:
    long = coordinate[0]
    lat = coordinate[1]
    path[index] = (lat, long)
    index += 1

folium.PolyLine(path, color='red', weight=2.5).add_to(world_map)
world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...
